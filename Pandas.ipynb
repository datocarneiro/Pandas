# %% [markdown]
# # pandas - "A melhor biblioteca do Python para Dados"
#
# - Quase sempre que você for trabalhar com dados no Python você vai usar o pandas, então é importante você saber trabalhar com essa biblioteca muito bem
#
# - Vamos aprender os principais comandos e os princípios básicos do pandas
#
# - Faça o download do Gabarito desse arquivo e use como uma cartilha de consulta (Link na descrição)

# %% [markdown]
# ### Importando o pandas

# %%
import pandas as pd

# %% [markdown]
# ### Criando um dataframe a partir de um dicionário

# %%
# dataframe = pd.DataFrame()
venda = {'data': ['15/02/2021', '16/02/2021'],
         'valor': [500, 300],
         'produto': ['feijao', 'arroz'],
         'qtde': [50, 70],
        }
vendas_df = pd.DataFrame(venda)

# %% [markdown]
# ### Visualização dos Dados
#     - print
#     - display

# %%
display(vendas_df)
# Out:
#          data  valor produto  qtde
# 0  15/02/2021    500  feijao    50
# 1  16/02/2021    300   arroz    70

# %% [markdown]
# ### Importando arquivos e bases de dados

# %%
vendas_df = pd.read_excel("Vendas.xlsx") #para ler o arquivo usa read_excel ou a extensão do arquivo poderia ser csv por exemplo, e dentro dos parenteses o nome do arquivo ou o path dele 
display(vendas_df)
# Out:
#     Numero de Ordem       Data Numero de origem                 Produto  \
# 0            301020 2019-01-01         Amplo-01          Sapato Estampa
# 1            301021 2019-01-01         Amplo-02                Camiseta
# 2            301022 2019-01-01         Amplo-03           Sapato Xadrez
# 3            301023 2019-01-02         Amplo-04                 Relógio
# 4            301024 2019-01-02         Amplo-05            Chinelo Liso
# 5            301025 2019-01-02         Amplo-06             Cinto Linho
# 6            301026 2019-01-02         Amplo-07                   Calça
# 7            301027 2019-01-02         Amplo-08           Polo Listrado
# 8            301028 2019-01-02         Amplo-09  Camisa Gola V Listrado
# 9            301029 2019-01-02         Amplo-10             Camisa Liso
# 10           301030 2019-01-02         Amplo-11           Terno Estampa
# 11           301031 2019-01-02         Amplo-12             Tênis Linho
# ...

# %% [markdown]
# ### Resumos de Visualização de Dados simples e úteis
#     - head -  dentro do parenteses() coloca quantas linhas quer visualizar, nesse caso coloquei 10, nesse exemplo i´ra mostrar da linha 0 à 9
#     - shape - retorna quantas linhas e colunas o arquivo tem
#     - describe - retorna um resumo

# %%
display(vendas_df.head(10))
print(vendas_df.shape)
display(vendas_df.describe())
# Out:
#    Numero de Ordem       Data Numero de origem                 Produto  \
# 0           301020 2019-01-01         Amplo-01          Sapato Estampa
# 1           301021 2019-01-01         Amplo-02                Camiseta
# 2           301022 2019-01-01         Amplo-03           Sapato Xadrez
# 3           301023 2019-01-02         Amplo-04                 Relógio
# 4           301024 2019-01-02         Amplo-05            Chinelo Liso
# 5           301025 2019-01-02         Amplo-06             Cinto Linho
# 6           301026 2019-01-02         Amplo-07                   Calça
# 7           301027 2019-01-02         Amplo-08           Polo Listrado
# 8           301028 2019-01-02         Amplo-09  Camisa Gola V Listrado
# 9           301029 2019-01-02         Amplo-10             Camisa Liso
#
#    Quantidade  Valor Unitário  Valor Final
# 0           1             358          358
# 1           2             180          360
# 2           1             368          368
# ...

# %% [markdown]
# ### Filtrando dados do dataframe, exemplo Pegar 1 coluna (e os pd.Series), uma coluna apenas podemos chamar de series, passando as colunas que queremos dentro dos [], cada coluna precisa ser aberto um colchetes[]

# %%
produtos = vendas_df[['Produto', 'Numero de Ordem']]
display(produtos)
# Out:
#                    Produto  Numero de Ordem
# 0           Sapato Estampa           301020
# 1                 Camiseta           301021
# 2            Sapato Xadrez           301022
# 3                  Relógio           301023
# 4             Chinelo Liso           301024
# 5              Cinto Linho           301025
# 6                    Calça           301026
# 7            Polo Listrado           301027
# 8   Camisa Gola V Listrado           301028
# 9              Camisa Liso           301029
# 10           Terno Estampa           301030
# 11             Tênis Linho           301031
# 12           Casaco Xadrez           301032
# 13         Camiseta Xadrez           301033
# 14              Cueca Liso           301034
# 15                Camiseta           301035
# 16          Calça Listrado           301036
# 17          Camisa Estampa           301037
# 18            Short Xadrez           301038
# 19              Sunga Liso           301039
# ...

# %% [markdown]
# ### .loc, um método muito importante
#     - Pegar 1 linha
#     - Pegar linhas de acordo com alguma condição
#     - Pegar linhas e colunas específicas
#     - Pegar 1 valor específico

# %%
# pegar uma linha
display(vendas_df.loc[1]) #aqui i´ra retornar como textoi e não como tabela 
print('=*'*45)
display(vendas_df.loc[1:5]) #aqui ja retona como tabela

print('=*'*45)
# pegar linhas que correspondem a uma condição, nesse exemplo quiz que retornasse somente as vendas do produto camisetas 
vendas_de_camisetas = vendas_df.loc[vendas_df['Produto'] == 'Camiseta']
display(vendas_de_camisetas)

print('=*'*45)
# pegar linhas que correspondem a uma condição, nesse exemplo quiz que retornasse somente as vendas do produto camisetas, mas quero apenas algumas colunas em especifico, uso loc[linhas, colunas]
vendas_norteshopping_df = vendas_df.loc[vendas_df['Produto'] == 'Camiseta', ["Numero de origem", "Valor Unitário"]]
display(vendas_norteshopping_df)

print('=*'*45)
# pegar 1 valor específico, passando a linha e a coluna, nesse exmplo retornar linha 1 e o valor da coluna Produto
print(vendas_df.loc[1, 'Produto'])
# Out:
# Numero de Ordem                  301021
# Data                2019-01-01 00:00:00
# Numero de origem               Amplo-02
# Produto                        Camiseta
# Quantidade                            2
# Valor Unitário                      180
# Valor Final                         360
# Comissão                           18.0
# Imposto                               0
# Name: 1, dtype: object
# =*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*
#    Numero de Ordem       Data Numero de origem        Produto  Quantidade  \
# 1           301021 2019-01-01         Amplo-02       Camiseta           2
# 2           301022 2019-01-01         Amplo-03  Sapato Xadrez           1
# 3           301023 2019-01-02         Amplo-04        Relógio           3
# 4           301024 2019-01-02         Amplo-05   Chinelo Liso           1
# 5           301025 2019-01-02         Amplo-06    Cinto Linho           1
#
# ...

# %% [markdown]
# ### Adicionar 1 coluna (importANTE O ARQUIVO ORIGINAL SERÁ ALTERADO)

# %%
# a partir de uma coluna que existe
vendas_df['Comissão'] = vendas_df['Valor Final'] * 0.05
display(vendas_df)

# criar uma coluna com valor padrão
vendas_df.loc[:, "Imposto"] = 0  #loc[linha,coluna ]
display(vendas_df)
# Out:
#     Numero de Ordem       Data Numero de origem                 Produto  \
# 0            301020 2019-01-01         Amplo-01          Sapato Estampa
# 1            301021 2019-01-01         Amplo-02                Camiseta
# 2            301022 2019-01-01         Amplo-03           Sapato Xadrez
# 3            301023 2019-01-02         Amplo-04                 Relógio
# 4            301024 2019-01-02         Amplo-05            Chinelo Liso
# 5            301025 2019-01-02         Amplo-06             Cinto Linho
# 6            301026 2019-01-02         Amplo-07                   Calça
# 7            301027 2019-01-02         Amplo-08           Polo Listrado
# 8            301028 2019-01-02         Amplo-09  Camisa Gola V Listrado
# 9            301029 2019-01-02         Amplo-10             Camisa Liso
# 10           301030 2019-01-02         Amplo-11           Terno Estampa
# 11           301031 2019-01-02         Amplo-12             Tênis Linho
# ...

# %% [markdown]
# ### Adicionar 1 linha
#     - Linhas de um complemento da base de dados

# %%
vendas_dez_df = pd.read_excel("Vendas - Dez.xlsx")
#display(vendas_dez_df)

vendas_df = vendas_df.append(vendas_dez_df)
display(vendas_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Windows\System32\config\systemprofile\AppData\Local\Temp\ipykernel_17812\3785904506.py in ?()
#       1 vendas_dez_df = pd.read_excel("Vendas - Dez.xlsx")
#       2 #display(vendas_dez_df)
#       3
# ----> 4 vendas_df = vendas_df.append(vendas_dez_df)
#       5 display(vendas_df)
#
# c:\Users\dato\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %% [markdown]
# ### Excluir linhas e colunas

# %%
vendas_df = vendas_df.drop(0, axis=0) # axis=0 será o eixo para linha, axis=1 será o eixo para as colunas 
display(vendas_df)
# Out:
#     Numero de Ordem       Data Numero de origem                 Produto  \
# 1            301021 2019-01-01         Amplo-02                Camiseta
# 2            301022 2019-01-01         Amplo-03           Sapato Xadrez
# 3            301023 2019-01-02         Amplo-04                 Relógio
# 4            301024 2019-01-02         Amplo-05            Chinelo Liso
# 5            301025 2019-01-02         Amplo-06             Cinto Linho
# 6            301026 2019-01-02         Amplo-07                   Calça
# 7            301027 2019-01-02         Amplo-08           Polo Listrado
# 8            301028 2019-01-02         Amplo-09  Camisa Gola V Listrado
# 9            301029 2019-01-02         Amplo-10             Camisa Liso
# 10           301030 2019-01-02         Amplo-11           Terno Estampa
# 11           301031 2019-01-02         Amplo-12             Tênis Linho
# 12           301032 2019-01-02         Amplo-13           Casaco Xadrez
# ...

# %% [markdown]
# ### Valores Vazios
#     - Deletar linhas/colunas vazias
#     - Deletar linhas que possuem valores vazios
#     - Preencher valores vazios (média e último valor)

# %%
# deletar linhas e colunas completamente vazias, onde não ha valor em nenhuma "celula"
#vendas_df = vendas_df.dropna(how='all', axis=1)

# deletar linhas que possuem pelo menos 1 valor vazio (se houiver apenas uma "celula" vazia irá excluir a linha inteira)
#vendas_df = vendas_df.dropna()

# preencher valores vazios
# preencher com a média da coluna
vendas_df['Comissão'] = vendas_df['Comissão'].fillna(vendas_df['Comissão'].mean()) # mean = média,  aqui prencido os valores vazio com a media da coluna comissão 
display(vendas_df)

# preencher com o último valor
vendas_df = vendas_df.ffill()
# Out:
#     Numero de Ordem       Data Numero de origem                 Produto  \
# 1            301021 2019-01-01         Amplo-02                Camiseta
# 2            301022 2019-01-01         Amplo-03           Sapato Xadrez
# 3            301023 2019-01-02         Amplo-04                 Relógio
# 4            301024 2019-01-02         Amplo-05            Chinelo Liso
# 5            301025 2019-01-02         Amplo-06             Cinto Linho
# 6            301026 2019-01-02         Amplo-07                   Calça
# 7            301027 2019-01-02         Amplo-08           Polo Listrado
# 8            301028 2019-01-02         Amplo-09  Camisa Gola V Listrado
# 9            301029 2019-01-02         Amplo-10             Camisa Liso
# 10           301030 2019-01-02         Amplo-11           Terno Estampa
# 11           301031 2019-01-02         Amplo-12             Tênis Linho
# 12           301032 2019-01-02         Amplo-13           Casaco Xadrez
# ...

# %% [markdown]
# ### Calcular Indicadores
#     - Groupby
#     - Value Counts

# %%
# value counts = contar valores 
transacoes_loja = vendas_df['Produto'].value_counts()
display(transacoes_loja)
# Out:
# Produto
# Camiseta                  2
# Chinelo Liso              2
# Camisa Estampa            2
# Casaco Xadrez             1
# Casaco Liso               1
# Sunga Liso                1
# Short Xadrez              1
# Calça Listrado            1
# Cueca Liso                1
# Camiseta Xadrez           1
# Tênis Linho               1
# Sapato Xadrez             1
# Terno Estampa             1
# Camisa Liso               1
# Camisa Gola V Listrado    1
# Polo Listrado             1
# Calça                     1
# Cinto Linho               1
# Relógio                   1
# Relógio Listrado          1
# Name: count, dtype: int64

# %%
# group by
faturamento_produto = vendas_df[['Produto', 'Valor Final']].groupby('Produto').sum() # aqui poderia ser media (mean) etc...
display(faturamento_produto)
# Out:
#                         Valor Final
# Produto
# Calça                           170
# Calça Listrado                  362
# Camisa Estampa                  226
# Camisa Gola V Listrado          116
# Camisa Liso                     105
# Camiseta                        540
# Camiseta Xadrez                 400
# Casaco Liso                     510
# Casaco Xadrez                   518
# Chinelo Liso                    142
# Cinto Linho                     248
# Cueca Liso                       69
# Polo Listrado                   596
# Relógio                         600
# Relógio Listrado                218
# Sapato Xadrez                   368
# Short Xadrez                    400
# Sunga Liso                      228
# Terno Estampa                  3530
# Tênis Linho                     294

# %% [markdown]
# ### Mesclar 2 dataframes (Procurar informações de um dataframe em outro) aqui o cabeçalho deve ser identico

# %%
gerentes_df = pd.read_excel("Gerentes.xlsx")
display(gerentes_df)

print('=*'*45)
vendas_df = vendas_df.merge(gerentes_df)
display(vendas_df)
# Out:
#    Numero de origem   Gerente
# 0          Amplo-01  Salvador
# 1          Amplo-02     Joana
# 2          Amplo-03     Maria
# 3          Amplo-04   Letícia
# 4          Amplo-05    Helena
# 5          Amplo-06     Luiza
# 6          Amplo-07     Julia
# 7          Amplo-08    Nicole
# 8          Amplo-09     André
# 9          Amplo-10      João
# 10         Amplo-11    Marcus
# 11         Amplo-12    Amanda
# 12         Amplo-13     Carol
# 13         Amplo-14  Andressa
# 14         Amplo-15     Lilia
# 15         Amplo-16     Paulo
# 16         Amplo-17     Pablo
# 17         Amplo-18     Diana
# 18         Amplo-19       Ana
# 19         Amplo-20    Flavia
# 20         Amplo-21  Fernanda
# 21         Amplo-22     Fábio
# 22         Amplo-23      Joel
# 23         Amplo-24    Gisele
# 24              NaN    Mateus
# =*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*
# ...

# %% [markdown]
# ### Como continuar aprendendo?
#
# ### Minicurso Gratuito de Análise de Dados com Python na Descrição
